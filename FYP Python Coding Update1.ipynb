# %% [markdown]
# Given the equations:
# \begin{eqnarray*}
# J_{i}&=&I_{i}\omega_{i}
# \\
# \dot{J_{i}} + ({\omega}+{J})&=&0
# \end{eqnarray*}
# We can derive the Ordinary Differential Equations for $J_{1}, J_{2}, J_{3}$, which can be displayed as:
# \begin{eqnarray*}
# \frac{dJ_{1}}{dt} &=&J_{2}J_{3} \frac{(I_{2}-I_{3})}{I_{2}I_{3}}
# \\
# \frac{dJ_{2}}{dt} &=&J_{1}J_{3} \frac{(I_{3}-I_{1})}{I_{1}I_{3}}
# \\
# \frac{dJ_{3}}{dt} &=&J_{1}J_{2} \frac{(I_{1}-I_{2})}{I_{1}I_{2}}
# \end{eqnarray*}

# %%
#imports
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
#Assigning I Values
I_1= 1;
I_2= 2;
I_3= 3;

#Initial J_{i} values
J_1, J_2, J_3 = 0.01,1,0.
#Resetting our J array for our graphs
J=[]

# %%
#ODE for J1, J2, J3
def dJ_dt(J,t): 
    return [J[1]*J[2]*((I_2 - I_3)/(I_2*I_3)), 
            J[0]*J[2]*((I_3 - I_1)/(I_1*I_3)), 
            J[0]*J[1]*((I_1 - I_2)/(I_1*I_2))]

# %%
# #ODE for J1, J2, J3
# def dJ_dt(J,t):
#     return[(Ji[1]*Ji[2]((I_2 - I_3)/(I_2*I_3))),(Ji[0]*Ji[2]((I_3 - I_1)/(I_1*I_3))),(Ji[0]*Ji[1]((I_1 - I_2)/(I_1*I_2)))]

# %%
#Setting the time frame
tmin=0
tmax=200

# %%
#Testers

# print(tmin)
# print(tmax)
# print(Ji[0])
# print(Ji[1])
# print(Ji[2])
# print(I_1)
# print(I_2)
# print(I_3)
# print(ts)

# %%
ts = np.linspace(tmin, tmax, 100) # 100 equally spaced t values from tmin to tmax 
Ji = [J_1, J_2,J_3] #initial conditions
Js = odeint(dJ_dt, Ji, ts)
J1 = Js[:,0] # values of J1 on ts values
J2 = Js[:,1] # values of J2 on ts values
J3 = Js[:,2] # values of J3 on ts values

# %%
plt.figure(3)
plt.plot(ts, J1, "-", label="J1 value")
plt.plot(ts, J2, "-", label="J2 value")
plt.plot(ts, J3, "-", label="J3 value")
plt.xlabel("Time")
plt.ylabel("J values")
plt.legend();

# %%
plt.figure(4)
#max line conditions
if max(J1)>= max(J2) and max(J1) >= max(J3):
    plt.plot([tmin,tmax],[max(J1),max(J1)],"b--")
    print("max J value =" , max(J1))
elif max(J2)>= max(J1) and max(J2) >= max(J3):
    plt.plot([tmin,tmax],[max(J2),max(J2)],"b--")
    print("max J value =" , max(J2))
else:
    plt.plot([tmin,tmax],[max(J3),max(J3)],"b--")
    print("max J value =", max(J3))
#min line conditions
if min(J1)<= min(J2) and min(J1) <= max(J3):
    plt.plot([tmin,tmax],[min(J1),min(J1)],"r--")
    print("min J value =",  min(J1))
elif min(J2)<= min(J1) and min(J2) <= max(J3):
    plt.plot([tmin,tmax],[min(J2),min(J2)],"r--")
    print("min J value =", min(J2))
else:
    plt.plot([tmin,tmax],[min(J3),min(J3)],"r--")
    print("min J value =" , min(J3))

plt.plot(ts, J1, "-", label="J1 value")
plt.plot(ts, J2, "-", label="J2 value")
plt.plot(ts, J3, "-", label="J2 value")
plt.xlabel("Time")
plt.ylabel("J values")
plt.legend();
# Out:
# max J value = 1.0
# min J value = -0.9999980618592895

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Create data
J1 = np.array([1,2,3])
J2 = np.array([2,3,4])
J3 = np.array([3,4,5])

# Create 3D Figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot 3D Object
ax.scatter(J1[0], J1[1], J1[2], c='r', marker='o')
ax.scatter(J2[0], J2[1], J2[2], c='g', marker='o')
ax.scatter(J3[0], J3[1], J3[2], c='b', marker='o')

# Show Plot
plt.show()

# Allow rotation
ax.azim += 15 # Rotate 10 degress around the z axis
ax.elev += 10 # Rotate 10 degrees around the x axis
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

jx = np.array([1,2,3,4]) # Set the components of J in x-direction
jy = np.array([2,4,6,7]) # Set the components of J in y-direction
jz = np.array([3,5,7,9]) # Set the components of J in z-direction

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = np.outer(np.cos(u), np.sin(v))
y = np.outer(np.sin(u), np.sin(v))
z = np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z,  rstride=4, cstride=4, color='b')
ax.plot(jx, jy, jz, 'rx')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Create a sphere
r = 2
pi = np.pi
cos = np.cos
sin = np.sin
phi, theta = np.mgrid[0.0:pi:100j, 0.0:2.0*pi:100j]
x = r*sin(phi)*cos(theta)
y = r*sin(phi)*sin(theta)
z = r*cos(phi)

phi2, theta2 = np.mgrid[0.0:pi:50j, 0.0:2.0*pi:50j]
X1 = 1*sin(phi2)*cos(theta2)
Y1 = 5*sin(phi2)*sin(theta2)
Z1 = 3*cos(phi2)
# Set the figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z,  rstride=3, cstride=3, color='b', alpha=0.5)
ax.plot_surface(X1, Y1, Z1,  rstride=3, cstride=3, color='r', alpha=0.5)
# Set the view rotation
ax.view_init(azim=45)

# # check if sphere and ellipsoid intersect
# if dist_center <= (radii[0] + sphere_radius):
#     print("Sphere and ellipsoid intersect!")
# else:
#     print("Sphere and ellipsoid do not intersect!")

# Show the plot
plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D  # Not needed with Matplotlib 3.6.3
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=plt.figaspect(1))  # Square figure
ax = fig.add_subplot(111, projection='3d')

coefs = (1, 2, 2)  # Coefficients in a0/c x**2 + a1/c y**2 + a2/c z**2 = 1 
# Radii corresponding to the coefficients:
rx, ry, rz = 1/np.sqrt(coefs)

# Set of all spherical angles:
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

# Cartesian coordinates that correspond to the spherical angles:
# (this is the equation of an ellipsoid):
x = rx * np.outer(np.cos(u), np.sin(v))
y = ry * np.outer(np.sin(u), np.sin(v))
z = rz * np.outer(np.ones_like(u), np.cos(v))

# Plot:
ax.plot_surface(x, y, z,  rstride=4, cstride=4, color='b')

# Adjustment of the axes, so that they all have the same span:
max_radius = max(rx, ry, rz)
for axis in 'xyz':
    getattr(ax, 'set_{}lim'.format(axis))((-max_radius, max_radius))

plt.show()
